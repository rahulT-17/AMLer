# %% [markdown]
# All the EDA of the dataset would take place here

# %%
# performing eda on the HISmallTrans.csv

import pandas as pd

df = pd.read_csv("data/HISmallTrans.csv")

df_sample = pd.read_csv("data/HISmallTrans.csv", nrows=1000)
df_sample.columns = [col.lower().replace(" ", "_") for col in df_sample.columns]
print(df_sample['is_laundering'].value_counts())


df.head(10)
# Out:
# is_laundering
# 0    1000
# Name: count, dtype: int64
#           Timestamp  From Bank    Account  To Bank  Account.1  \
# 0  2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1  2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2  2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3  2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4  2022/09/01 00:06         10  8000F5200       10  8000F5200
# 5  2022/09/01 00:03          1  8000F5AD0        1  8000F5AD0
# 6  2022/09/01 00:08          1  8000EBAC0        1  8000EBAC0
# 7  2022/09/01 00:16          1  8000EC1E0        1  8000EC1E0
# 8  2022/09/01 00:26         12  8000EC280     2439  8017BF800
# 9  2022/09/01 00:21          1  8000EDEC0   211050  80AEF5310
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34          US Dollar      3697.34        US Dollar
# 1             0.01          US Dollar         0.01        US Dollar
# ...

# %%
# listing all the columns in the dataset
df.columns.tolist()
# Out:
# ['Timestamp',
#  'From Bank',
#  'Account',
#  'To Bank',
#  'Account.1',
#  'Amount Received',
#  'Receiving Currency',
#  'Amount Paid',
#  'Payment Currency',
#  'Payment Format',
#  'Is Laundering']

# %%
df.dtypes
# Out:
# Timestamp              object
# From Bank               int64
# Account                object
# To Bank                 int64
# Account.1              object
# Amount Received       float64
# Receiving Currency     object
# Amount Paid           float64
# Payment Currency       object
# Payment Format         object
# Is Laundering           int64
# dtype: object

# %%
# checking for islaundering :
df['Is Laundering'].value_counts()
# Out:
# Is Laundering
# 0    5073168
# 1       5177
# Name: count, dtype: int64

# %%
# checking the shape of the dataset
df.shape
# Out:
# (5078345, 11)

# %%
# looking for unique values :
df['Receiving Currency'].unique()

print(df['Is Laundering'].value_counts())
print(df['Is Laundering'].mean())

# amount stats for laundering transactions :
print("Payment format for laundering and amount paid stats for laundering transactions :")
laundering = df[df['Is Laundering'] == 1]
print(laundering['Payment Format'].value_counts())
print(laundering['Amount Paid'].describe())
# Out:
# Is Laundering
# 0    5073168
# 1       5177
# Name: count, dtype: int64
# 0.0010194266045335635
# Payment format for laundering and amount paid stats for laundering transactions :
# Payment Format
# ACH            4483
# Cheque          324
# Credit Card     206
# Cash            108
# Bitcoin          56
# Name: count, dtype: int64
# count    5.177000e+03
# mean     3.613531e+07
# std      1.527919e+09
# min      3.227000e-03
# 25%      2.634970e+03
# 50%      8.667210e+03
# 75%      1.883227e+04
# max      8.485314e+10
# Name: Amount Paid, dtype: float64
